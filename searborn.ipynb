# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.scatterplot(data=iris,x=iris['petal_length'],y=iris['petal_width'])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris,x=iris['sepal_length'],y=iris['sepal_width'],hue=iris['species'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Visualizing statstical relationships

# %%
tips= sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()
sns.relplot(data=tips,x=tips['total_bill'],y=tips['tip'])

# %%
sns.relplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['smoker'])

# %%
sns.relplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'])

# %%
sns.relplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'])

# %%
sns.relplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['time'])

# %%
tips['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization categorical data

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=tips,x=tips['day'],y=tips['total_bill'])

# %%
sns.catplot(data=tips,x=tips['day'],y=tips['total_bill'],hue=tips['sex'],kind='swarm')

# %%
sns.catplot(data=tips,x=tips['day'],y=tips['total_bill'],hue=tips['time'],kind='swarm')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=tips,x=tips['day'],y=tips['total_bill'],hue=tips['size'],kind='swarm')

# %%
sns.catplot(data=tips,x=tips['day'],y=tips['tip'],hue=tips['time'],kind='violin')

# %% [markdown]
# ## Visualizing distribution data

# %%
sns.displot(data=tips,x=tips['total_bill'])

# %%
sns.displot(data=tips,x=tips['tip'])

# %%
sns.displot(data=tips,x=tips['total_bill'],kind='kde')

# %%
sns.displot(data=tips,x=tips['total_bill'],kde=True)

# %%
sns.displot(data=tips,x=tips['total_bill'],col=tips['time'],kde=True)

# %%
sns.displot(data=tips,x=tips['total_bill'],col=tips['sex'],kde=True)

# %%
sns.displot(data=tips,x=tips['total_bill'],col=tips['smoker'],kde=True)

# %%
sns.displot(data=tips,x=tips['total_bill'],col=tips['smoker'],hue=tips['time'],kde=True)

# %%
sns.jointplot(data=iris,x=iris['petal_length'],y=iris['sepal_length'],hue=iris['species'])

# %%
sns.jointplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['day'])

# %%
sns.jointplot(data=tips,x=tips['total_bill'],y=tips['tip'],hue=tips['sex'])

# %%
sns.pairplot(data=tips)

# %%
sns.pairplot(data=iris)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.relplot(data=df,x=df['Age'],y=df['Fare'])

# %%
sns.relplot(data=df,x=df['Age'],y=df['Fare'],hue=df['Pclass'],style=df['Survived'])

# %%
sns.displot(data=df,x=df['Age'],col=df['Pclass'],kde=True,hue=df['Sex'])
